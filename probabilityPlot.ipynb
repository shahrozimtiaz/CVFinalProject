# %%
import matplotlib.pyplot as plt

# %%
accuracies = []
accuracies.append('Face detected with probability: 0.999982'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999933'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999994'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999998'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999866'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999999'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999999'.split(':')[1].strip())
accuracies.append('Face detected with probability: 1.000000'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999719'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999887'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999998'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999994'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999984'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999994'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999997'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999993'.split(':')[1].strip())
accuracies.append('Face detected with probability: 0.999992'.split(':')[1].strip())

# %%
plt.plot(range(len(accuracies)),accuracies)
plt.xlabel('image')
plt.ylabel('probability percentage')
plt.legend(['probability'], loc='lower right')
plt.show()
